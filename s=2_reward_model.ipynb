# %%
import torch
import torch.nn as nn
import torch.utils.model_zoo as model_zoo
import torch.nn.functional as F

from resnet_features import resnet18_features, resnet34_features, resnet50_features, resnet101_features, resnet152_features
from densenet_features import densenet121_features, densenet161_features, densenet169_features, densenet201_features
from vgg_features import vgg11_features, vgg11_bn_features, vgg13_features, vgg13_bn_features, vgg16_features, vgg16_bn_features,\
                         vgg19_features, vgg19_bn_features

from receptive_field import compute_proto_layer_rf_info_v2

from settings import img_size

from PIL import Image
import numpy as np
import numpy.random as npr
import pandas as pd
import os
import matplotlib.pyplot as plt
import torch.utils.data
# import torch.utils.data.distributed
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.optim as optim

import pickle as pkl
import skimage as sk
import skimage.io as skio
from preference_model import construct_PrefNet, paired_cross_entropy_loss, PrefNet

# book keeping namings and code
from settings import base_architecture, img_size, prototype_shape, num_classes, \
                     prototype_activation_function, add_on_layers_type, experiment_run

from preprocess import mean, std, preprocess_input_function
from tqdm import tqdm

# %%
base_architecture_to_features = {'resnet18': resnet18_features,
                                 'resnet34': resnet34_features,
                                 'resnet50': resnet50_features,
                                 'resnet101': resnet101_features,
                                 'resnet152': resnet152_features,
                                 'densenet121': densenet121_features,
                                 'densenet161': densenet161_features,
                                 'densenet169': densenet169_features,
                                 'densenet201': densenet201_features,
                                 'vgg11': vgg11_features,
                                 'vgg11_bn': vgg11_bn_features,
                                 'vgg13': vgg13_features,
                                 'vgg13_bn': vgg13_bn_features,
                                 'vgg16': vgg16_features,
                                 'vgg16_bn': vgg16_bn_features,
                                 'vgg19': vgg19_features,
                                 'vgg19_bn': vgg19_bn_features}


class PrefNet(nn.Module):

    def __init__(self, img_features, pattern_features, img_size, prototype_shape,
                 proto_layer_rf_info, num_classes, init_weights=False,
                 prototype_activation_function='log',
                 add_on_layers_type='bottleneck', 
                k = 1):

        super(PrefNet, self).__init__()
        self.img_size = img_size
        self.prototype_shape = prototype_shape
        self.num_prototypes = prototype_shape[0]
        self.num_classes = num_classes
        self.epsilon = 1e-4
        self.k = k
        
        # this has to be named features to allow the precise loading
        self.img_features = img_features
        self.pattern_features = pattern_features
        
        '''
        features_name = str(self.features).upper()
        if features_name.startswith('VGG') or features_name.startswith('RES'):
            first_add_on_layer_in_channels = \
                [i for i in features.modules() if isinstance(i, nn.Conv2d)][-1].out_channels
        elif features_name.startswith('DENSE'):
            first_add_on_layer_in_channels = \
                [i for i in features.modules() if isinstance(i, nn.BatchNorm2d)][-1].num_features
        else:
            raise Exception('other base base_architecture NOT implemented')
        '''
        
        '''    
        if add_on_layers_type == 'bottleneck':
            add_on_layers = []
            current_in_channels = first_add_on_layer_in_channels
            while (current_in_channels > self.prototype_shape[1]) or (len(add_on_layers) == 0):
                current_out_channels = max(self.prototype_shape[1], (current_in_channels // 2))
                add_on_layers.append(nn.Conv2d(in_channels=current_in_channels,
                                               out_channels=current_out_channels,
                                               kernel_size=1))
                add_on_layers.append(nn.ReLU())
                add_on_layers.append(nn.Conv2d(in_channels=current_out_channels,
                                               out_channels=current_out_channels,
                                               kernel_size=1))
                if current_out_channels > self.prototype_shape[1]:
                    add_on_layers.append(nn.ReLU())
                else:
                    assert(current_out_channels == self.prototype_shape[1])
                    add_on_layers.append(nn.Sigmoid())
                current_in_channels = current_in_channels // 2
            self.add_on_layers = nn.Sequential(*add_on_layers)
        else:
            self.add_on_layers = nn.Sequential(
                nn.Conv2d(in_channels=first_add_on_layer_in_channels, out_channels=self.prototype_shape[1], kernel_size=1),
                nn.ReLU(),
                nn.Conv2d(in_channels=self.prototype_shape[1], out_channels=self.prototype_shape[1], kernel_size=1),
                nn.Sigmoid()
                )
        
        '''
                
#         self.prototype_vectors = nn.Parameter(torch.rand(self.prototype_shape),
#                                               requires_grad=True)

#         # do not make this just a tensor,
#         # since it will not be moved automatically to gpu
#         self.ones = nn.Parameter(torch.ones(self.prototype_shape),
#                                  requires_grad=False)

#         self.last_layer = nn.Linear(self.num_prototypes, self.num_classes,
#                                     bias=False) # do not use bias
    

        self.img_conv = nn.Sequential(
            nn.Conv2d(in_channels=2048, out_channels=512, kernel_size=5),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=128, kernel_size=3),
            nn.Sigmoid()
            )
        
        self.pattern_conv = nn.Sequential(
            nn.Conv2d(in_channels=2048, out_channels=512, kernel_size=5),
            nn.ReLU(),
            nn.Conv2d(in_channels=512, out_channels=128, kernel_size=3),
            nn.Sigmoid()
            )
        
        self.final_fc = nn.Sequential(
            nn.Linear(256, 32),
            nn.ReLU(),
            nn.Sigmoid(),
            nn.Linear(32, 1),
            nn.Sigmoid()
        
            )
        
        #self.fc1 = nn.Linear(6400, 512)
        #self.fc2 = nn.Linear(512, 32)
        #self.fc3 = nn.Linear(32, 1)
        #self.fc1 = nn.Linear(64, 16)
        

        if init_weights:
            self._initialize_weights()
            
            
    def conv_features(self, x):
        '''
        the feature input to prototype layer
        '''
        # Insert k and then img size
        x = self.features(x)
        #print("base features: ", x.shape)
        #x = self.add_on_layers(x)
        return x
    
    def forward(self, x, p):
        # (N, 512, 7, 7)
        #x = self.conv_features(x)
        x = self.img_features(x)
        #x = self.add_on_layers(x)
        x = self.img_conv(x)
        #print("conv out:", x.shape)
        p = self.pattern_features(p)
        #p = self.conv_features(p)
        #p = self.add_on_layers(p)
        p = self.pattern_conv(p)
        
        out = torch.cat((x, p), dim=1)
        #print("cat out shape: ", out.shape)
        out = torch.flatten(out, 1) 
        #print("flatten out shape: ", out.shape)
        
        out = self.final_fc(out)
        #out = torch.sigmoid(self.fc1(out))
        #out = torch.sigmoid(self.fc2(out))
        #out = self.fc3(out)
        return out

    
    def _initialize_weights(self):
        for m in self.img_conv.modules():
            if isinstance(m, nn.Conv2d):
                # every init technique has an underscore _ in the name
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
                
        for m in self.pattern_conv.modules():
            if isinstance(m, nn.Conv2d):
                # every init technique has an underscore _ in the name
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)




            
def construct_PrefNet(base_architecture, pretrained=True, img_size=224,
                    prototype_shape=(1000, 128, 1, 1), num_classes=200,
                    prototype_activation_function='log',
                    add_on_layers_type='bottleneck',
                    k = 1):
    img_features = base_architecture_to_features[base_architecture](pretrained=pretrained)
    pattern_features = base_architecture_to_features[base_architecture](pretrained=pretrained)
    layer_filter_sizes, layer_strides, layer_paddings = img_features.conv_info()
    proto_layer_rf_info = compute_proto_layer_rf_info_v2(img_size=img_size,
                                                         layer_filter_sizes=layer_filter_sizes,
                                                         layer_strides=layer_strides,
                                                         layer_paddings=layer_paddings,
                                                         prototype_kernel_size=prototype_shape[2])
    return PrefNet(img_features=img_features,
                   pattern_features=pattern_features,
                 img_size=img_size,
                 prototype_shape=prototype_shape,
                 proto_layer_rf_info=proto_layer_rf_info,
                 num_classes=num_classes,
                 init_weights=True,
                 prototype_activation_function=prototype_activation_function,
                 add_on_layers_type=add_on_layers_type,
                 k = k)


def paired_cross_entropy_loss(out1, out2, targets):
    
    total_loss = 0
    for i in range(len(targets)):
        
        if targets[i] == -1:
            p1 = torch.exp(out1[i])/(torch.exp(out1[i]) + torch.exp(out2[i]))
            loss = - torch.log(p1)
        elif targets[i] == 1:
            p2 = torch.exp(out2[i])/(torch.exp(out1[i]) + torch.exp(out2[i]))
            loss = - torch.log(p2)

        else:
            p1 = torch.exp(out1[i])/(torch.exp(out1[i]) + torch.exp(out2[i]))
            p2 = torch.exp(out2[i])/(torch.exp(out1[i]) + torch.exp(out2[i]))
            loss = - (0.5*torch.log(p1) + 0.5*torch.log(p2))
            
        total_loss += loss
    return total_loss

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print('Using {} device'.format(device))
# Out:
# Using cuda device

# %%
normalize = transforms.Normalize(mean=mean,
                                 std=std)

trans = transforms.Compose([
    transforms.Resize(size=(img_size, img_size)),
    transforms.ToTensor(),
    normalize
])

# %%
k = 1
csv_name = "./human_comparisons/rating_s=5_k=1_700_random_1.csv"
if os.path.exists(csv_name):
    comp_df = pd.read_csv(csv_name)

# %%
split = 0.7
df_len = len(comp_df)
train_set = []
test_set = []
split_idx = int(df_len*split)
for i in range(split_idx):
    for j in range(i+1, split_idx):
        if comp_df.iloc[i]['rating'] > comp_df.iloc[j]['rating']:
            train_set.append([i, j, -1])
        elif comp_df.iloc[i]['rating'] < comp_df.iloc[j]['rating']:
            train_set.append([i, j, 1])
            
for i in range(split_idx, df_len):
    for j in range(i+1, df_len):
        if comp_df.iloc[i]['rating'] > comp_df.iloc[j]['rating']:
            test_set.append([i, j, -1])
        elif comp_df.iloc[i]['rating'] < comp_df.iloc[j]['rating']:
            test_set.append([i, j, 1])
print(len(train_set))
print(len(test_set))
# Out:
# 71875
# 13831

# %%
images = []
patterns = []
for i in range(df_len):
    img = './human_comparisons/feedback_images/k=1_random/original_imgs/' + comp_df.iloc[i]['imgid'] + '.png'
    img = plt.imread(img)[:, :, :3]
    img = np.transpose(img, (2, 0, 1))
    images.append(torch.from_numpy(np.array([img])))
    pattern = './human_comparisons/feedback_images/k=1_random/patterns/' + comp_df.iloc[i]['imgid'] + '.npy'
    pattern = np.load(pattern)
    pattern = np.array([pattern, pattern, pattern])
    patterns.append(torch.from_numpy(np.array([pattern])))
print(len(images))
print(images[100].shape)
print(patterns[100].shape)
# Out:
# 700
# torch.Size([1, 3, 224, 224])
# torch.Size([1, 3, 224, 224])

# %%
prefnet = construct_PrefNet("resnet50")
prefnet.to(device)
prefnet.train()

for p in prefnet.final_fc.parameters():
    p.requires_grad = True
for p in prefnet.img_features.parameters():
    p.requires_grad = True
for p in prefnet.pattern_features.parameters():
    p.requires_grad = True
for p in prefnet.img_conv.parameters():
    p.requires_grad = True
for p in prefnet.pattern_conv.parameters():
    p.requires_grad = True

pref_optimizer = optim.Adam([{'params': prefnet.img_features.parameters(), 'lr': 1e-4, 'weight_decay':1e-4}, {'params': prefnet.pattern_features.parameters(), 'lr': 1e-4, 'weight_decay':1e-4},
                             #{'params': prefnet.add_on_layers.parameters(), 'lr': 1e-4}, 
                             {'params': prefnet.img_conv.parameters(), 'lr': 1e-4, 'weight_decay':1e-4}, {'params': prefnet.pattern_conv.parameters(), 'lr': 1e-4, 'weight_decay':1e-4}, 
                             {'params': prefnet.final_fc.parameters(), 'lr': 1e-4, 'weight_decay':1e-4}
                             #{'params': prefnet.fc1.parameters(), 'lr': 1e-4}, {'params': prefnet.fc2.parameters(), 'lr': 1e-4}, {'params': prefnet.fc3.parameters(), 'lr': 1e-4}
                             ])

# %%
lr = 1e-5
weight_decay = 1e-5
pref_optimizer = optim.Adam([{'params': prefnet.img_features.parameters(), 'lr': lr, 'weight_decay':weight_decay}, {'params': prefnet.pattern_features.parameters(), 'lr': lr, 'weight_decay':weight_decay},
                             #{'params': prefnet.add_on_layers.parameters(), 'lr': 1e-4}, 
                             {'params': prefnet.img_conv.parameters(), 'lr': lr, 'weight_decay':weight_decay}, {'params': prefnet.pattern_conv.parameters(), 'lr': lr, 'weight_decay':weight_decay}, 
                             {'params': prefnet.final_fc.parameters(), 'lr': lr, 'weight_decay':weight_decay}
                             #{'params': prefnet.fc1.parameters(), 'lr': 1e-4}, {'params': prefnet.fc2.parameters(), 'lr': 1e-4}, {'params': prefnet.fc3.parameters(), 'lr': 1e-4}
                             ])

# %%
epochs = 5
batch_size = 16

# %%
prefnet(images[9].cuda(), patterns[9].cuda())
# Out:
# tensor([[0.0273]], device='cuda:0', grad_fn=<SigmoidBackward0>)

# %%
def test_reward_model(prefnet, test_set, images, patterns, batch_size):
    acc = []
    error_count = 0
    all_idx = np.arange(len(test_set))
    for batch_i in tqdm(range(len(test_set)//batch_size + 1)):
        prefnet.eval()
        
        idx = all_idx[batch_i*batch_size:(batch_i+1)*batch_size]
        
        left_imgs = torch.zeros((batch_size, 3, 224, 224))
        right_imgs = torch.zeros((batch_size, 3, 224, 224))
        left_patterns = torch.zeros((batch_size, 3, 224, 224))
        right_patterns = torch.zeros((batch_size, 3, 224, 224))
        targets = []
        for i in range(len(idx)):
            index = idx[i]
            left_imgs[i] = images[test_set[index][0]][0]
            right_imgs[i] = images[test_set[index][1]][0]
            targets.append(test_set[index][2])
            left_patterns[i] = patterns[test_set[index][0]][0]
            right_patterns[i] = patterns[test_set[index][1]][0]
        
        targets = torch.tensor(targets).cuda().float()
        
        out1 = prefnet(left_imgs.cuda().float(), left_patterns.cuda().float())
        out2 = prefnet(right_imgs.cuda().float(), right_patterns.cuda().float())

        
        
        for i in range(len(targets)):

            if out1[i] > out2[i]:
                y_pred = -1

            else:
                y_pred = 1

            
            if y_pred == targets[i]:
                acc.append(1)
        else:
            
            error_count += 1
            acc.append(0)
            
    return np.mean(acc), error_count

# %%
for epoch in range(epochs):
    shuffled_idx = np.random.permutation(len(train_set))
    for batch_i in range(len(train_set)//batch_size + 1):
        prefnet.train()
        if batch_i % 100 == 0:
            last_100_losses = []
            last_100_error_count = 0
        idx = shuffled_idx[batch_i*batch_size:(batch_i+1)*batch_size]
        
        left_imgs = torch.zeros((batch_size, 3, 224, 224))
        right_imgs = torch.zeros((batch_size, 3, 224, 224))
        left_patterns = torch.zeros((batch_size, 3, 224, 224))
        right_patterns = torch.zeros((batch_size, 3, 224, 224))
        targets = []
        for i in range(len(idx)):
            index = idx[i]
            left_imgs[i] = images[train_set[index][0]][0]
            right_imgs[i] = images[train_set[index][1]][0]
            targets.append(train_set[index][2])
            left_patterns[i] = patterns[train_set[index][0]][0]
            right_patterns[i] = patterns[train_set[index][1]][0]
        
        targets = torch.tensor(targets).cuda().float()
        
        out1 = prefnet(left_imgs.cuda().float(), left_patterns.cuda().float())
        out2 = prefnet(right_imgs.cuda().float(), right_patterns.cuda().float())

        
        pref_optimizer.zero_grad()   
        
        for i in range(len(targets)):
            if out1[i] > out2[i] and targets[i] == 1:
                last_100_error_count += 1

            elif out1[i] < out2[i] and targets[i] == -1:
                last_100_error_count += 1
                
        loss = paired_cross_entropy_loss(out1, out2, targets)
        
        loss.backward()
        pref_optimizer.step()   
        
        last_100_losses.append(loss.data.cpu().numpy()[0])
        
        if batch_i % 100 == 0:
            print(epoch, batch_i, np.sum(last_100_losses))
        if batch_i % 100 == 99:
            print(epoch, batch_i, last_100_error_count)
        if batch_i % 2000 == 1999:
            
            test_acc, test_error_count = test_reward_model(prefnet, test_set, images, patterns, batch_size)
            print(epoch, batch_i, test_acc, test_error_count)
# Out:
# 0 0 7.7368217
# 0 99 98
# 0 100 6.6764493
# 0 199 95
# 0 200 7.047304
# 0 299 101
# 0 300 5.9509435
# 0 399 93
# 0 400 6.566382
# 0 499 92
# 0 500 6.3128304
# 0 599 90
# 0 600 6.678241
# 0 699 104
# 0 700 6.6762857
# 0 799 90
# 0 800 5.957803
# 0 899 89
# 0 900 7.04094
# 0 999 109
# 0 1000 6.305628
# 0 1099 108
# 0 1100 7.4081235
# 0 1199 109
# 0 1200 6.694401
# 0 1299 105
# 0 1300 5.564393
# 0 1399 105
# 0 1400 6.668639
# 0 1499 94
# 0 1500 7.006999
# 0 1599 115
# 0 1600 6.6676965
# 0 1699 99
# 0 1700 6.664954
# 0 1799 105
# 0 1800 7.4009433
# 0 1899 123
# 0 1900 6.294656
# 0 1999 103
# 100%|██████████| 865/865 [00:46<00:00, 18.63it/s]
# 0 1999 0.9142800515310673 865
# 0 2000 7.0306573
# 0 2099 120
# 0 2100 6.2919474
# 0 2199 101
# 0 2200 7.029771
# 0 2299 96
# 0 2300 6.6597095
# 0 2399 102
# 0 2400 6.289434
# 0 2499 100
# 0 2500 6.6577916
# 0 2599 104
# 0 2600 5.916775
# 0 2699 106
# 0 2700 6.6560087
# 0 2799 126
# 0 2800 6.28539
# 0 2899 100
# 0 2900 6.2849874
# 0 2999 69
# 0 3000 5.913496
# 0 3099 91
# 0 3100 6.282184
# 0 3199 112
# 0 3200 6.6511188
# 0 3299 105
# 0 3300 6.49632
# 0 3399 94
# 0 3400 6.279418
# 0 3499 96
# 0 3500 5.9084477
# 0 3599 104
# 0 3600 6.647893
# 0 3699 114
# 0 3700 6.56309
# 0 3799 124
# 0 3800 5.5354056
# 0 3899 114
# 0 3900 7.3863378
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 40
#      36         last_100_error_count += 1
#      38 loss = paired_cross_entropy_loss(out1, out2, targets)
# ---> 40 loss.backward()
#      41 pref_optimizer.step()
#      43 last_100_losses.append(loss.data.cpu().numpy()[0])
#
# File /usr/local/linux/mambaforge-3.11/lib/python3.11/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File /usr/local/linux/mambaforge-3.11/lib/python3.11/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
torch.save(prefnet, './human_comparisons/pref_model_700_random_rating_split0.7_acc0.915.pth')

# %%
for i in range(df_len):
    score = prefnet(images[i].cuda(), patterns[i].cuda()).data
    print(i, comp_df.iloc[i]['rating'], score)
# Out:
# 0 5.0 tensor([[0.9832]], device='cuda:0')
# 1 5.0 tensor([[0.9832]], device='cuda:0')
# 2 5.0 tensor([[0.9832]], device='cuda:0')
# 3 3.0 tensor([[0.0178]], device='cuda:0')
# 4 4.0 tensor([[0.9792]], device='cuda:0')
# 5 4.0 tensor([[0.0396]], device='cuda:0')
# 6 2.0 tensor([[0.0178]], device='cuda:0')
# 7 5.0 tensor([[0.9831]], device='cuda:0')
# 8 5.0 tensor([[0.9831]], device='cuda:0')
# 9 1.0 tensor([[0.0187]], device='cuda:0')
# 10 1.0 tensor([[0.0194]], device='cuda:0')
# 11 4.0 tensor([[0.1502]], device='cuda:0')
# 12 5.0 tensor([[0.9832]], device='cuda:0')
# 13 4.0 tensor([[0.5484]], device='cuda:0')
# 14 4.0 tensor([[0.0179]], device='cuda:0')
# 15 5.0 tensor([[0.9831]], device='cuda:0')
# 16 5.0 tensor([[0.9831]], device='cuda:0')
# 17 5.0 tensor([[0.9831]], device='cuda:0')
# 18 5.0 tensor([[0.9831]], device='cuda:0')
# 19 1.0 tensor([[0.0179]], device='cuda:0')
# 20 3.0 tensor([[0.0184]], device='cuda:0')
# 21 5.0 tensor([[0.9832]], device='cuda:0')
# 22 2.0 tensor([[0.0178]], device='cuda:0')
# 23 2.0 tensor([[0.0178]], device='cuda:0')
# 24 2.0 tensor([[0.0178]], device='cuda:0')
# 25 5.0 tensor([[0.9830]], device='cuda:0')
# 26 5.0 tensor([[0.9419]], device='cuda:0')
# 27 5.0 tensor([[0.7333]], device='cuda:0')
# 28 5.0 tensor([[0.0190]], device='cuda:0')
# 29 5.0 tensor([[0.9531]], device='cuda:0')
# 30 5.0 tensor([[0.9831]], device='cuda:0')
# 31 5.0 tensor([[0.9831]], device='cuda:0')
# 32 4.0 tensor([[0.1533]], device='cuda:0')
# 33 4.0 tensor([[0.0179]], device='cuda:0')
# 34 5.0 tensor([[0.9831]], device='cuda:0')
# 35 5.0 tensor([[0.9832]], device='cuda:0')
# 36 5.0 tensor([[0.9832]], device='cuda:0')
# 37 1.0 tensor([[0.0178]], device='cuda:0')
# 38 5.0 tensor([[0.9831]], device='cuda:0')
# 39 1.0 tensor([[0.0178]], device='cuda:0')
# 40 5.0 tensor([[0.9831]], device='cuda:0')
# 41 5.0 tensor([[0.9831]], device='cuda:0')
# 42 5.0 tensor([[0.9831]], device='cuda:0')
# 43 5.0 tensor([[0.9831]], device='cuda:0')
# 44 4.0 tensor([[0.0179]], device='cuda:0')
# 45 5.0 tensor([[0.9832]], device='cuda:0')
# 46 1.0 tensor([[0.0179]], device='cuda:0')
# 47 5.0 tensor([[0.9832]], device='cuda:0')
# 48 5.0 tensor([[0.9832]], device='cuda:0')
# 49 5.0 tensor([[0.9828]], device='cuda:0')
# 50 2.0 tensor([[0.0178]], device='cuda:0')
# 51 5.0 tensor([[0.9832]], device='cuda:0')
# 52 5.0 tensor([[0.9831]], device='cuda:0')
# 53 5.0 tensor([[0.9832]], device='cuda:0')
# 54 1.0 tensor([[0.0178]], device='cuda:0')
# 55 5.0 tensor([[0.9832]], device='cuda:0')
# 56 1.0 tensor([[0.0178]], device='cuda:0')
# 57 5.0 tensor([[0.9832]], device='cuda:0')
# 58 2.0 tensor([[0.0178]], device='cuda:0')
# 59 1.0 tensor([[0.0178]], device='cuda:0')
# 60 4.0 tensor([[0.0185]], device='cuda:0')
# 61 5.0 tensor([[0.9831]], device='cuda:0')
# 62 3.0 tensor([[0.0183]], device='cuda:0')
# 63 4.0 tensor([[0.0198]], device='cuda:0')
# 64 5.0 tensor([[0.9831]], device='cuda:0')
# 65 5.0 tensor([[0.9830]], device='cuda:0')
# 66 2.0 tensor([[0.0178]], device='cuda:0')
# 67 5.0 tensor([[0.9832]], device='cuda:0')
# 68 2.0 tensor([[0.0178]], device='cuda:0')
# 69 5.0 tensor([[0.9832]], device='cuda:0')
# 70 5.0 tensor([[0.9831]], device='cuda:0')
# 71 5.0 tensor([[0.9830]], device='cuda:0')
# 72 5.0 tensor([[0.9831]], device='cuda:0')
# 73 2.0 tensor([[0.0178]], device='cuda:0')
# 74 3.0 tensor([[0.0182]], device='cuda:0')
# 75 5.0 tensor([[0.3465]], device='cuda:0')
# 76 5.0 tensor([[0.9832]], device='cuda:0')
# 77 4.0 tensor([[0.0181]], device='cuda:0')
# 78 5.0 tensor([[0.7519]], device='cuda:0')
# 79 5.0 tensor([[0.9832]], device='cuda:0')
# 80 5.0 tensor([[0.9831]], device='cuda:0')
# 81 5.0 tensor([[0.8261]], device='cuda:0')
# 82 1.0 tensor([[0.0178]], device='cuda:0')
# 83 5.0 tensor([[0.9831]], device='cuda:0')
# 84 5.0 tensor([[0.9809]], device='cuda:0')
# 85 5.0 tensor([[0.9832]], device='cuda:0')
# 86 2.0 tensor([[0.0179]], device='cuda:0')
# 87 4.0 tensor([[0.0179]], device='cuda:0')
# 88 5.0 tensor([[0.9339]], device='cuda:0')
# 89 2.0 tensor([[0.0179]], device='cuda:0')
# 90 4.0 tensor([[0.0180]], device='cuda:0')
# 91 4.0 tensor([[0.0183]], device='cuda:0')
# 92 5.0 tensor([[0.3269]], device='cuda:0')
# 93 3.0 tensor([[0.0179]], device='cuda:0')
# 94 4.0 tensor([[0.0179]], device='cuda:0')
# 95 5.0 tensor([[0.9521]], device='cuda:0')
# 96 5.0 tensor([[0.9831]], device='cuda:0')
# 97 5.0 tensor([[0.9831]], device='cuda:0')
# 98 4.0 tensor([[0.9823]], device='cuda:0')
# 99 5.0 tensor([[0.9831]], device='cuda:0')
# 100 5.0 tensor([[0.9832]], device='cuda:0')
# 101 1.0 tensor([[0.0178]], device='cuda:0')
# 102 5.0 tensor([[0.9832]], device='cuda:0')
# 103 5.0 tensor([[0.9832]], device='cuda:0')
# 104 5.0 tensor([[0.9832]], device='cuda:0')
# 105 1.0 tensor([[0.0178]], device='cuda:0')
# 106 5.0 tensor([[0.9832]], device='cuda:0')
# 107 1.0 tensor([[0.0178]], device='cuda:0')
# 108 5.0 tensor([[0.9832]], device='cuda:0')
# 109 5.0 tensor([[0.9832]], device='cuda:0')
# 110 5.0 tensor([[0.9832]], device='cuda:0')
# 111 5.0 tensor([[0.9832]], device='cuda:0')
# 112 3.0 tensor([[0.0178]], device='cuda:0')
# 113 5.0 tensor([[0.9832]], device='cuda:0')
# 114 3.0 tensor([[0.0178]], device='cuda:0')
# 115 5.0 tensor([[0.9831]], device='cuda:0')
# 116 5.0 tensor([[0.9832]], device='cuda:0')
# 117 5.0 tensor([[0.9831]], device='cuda:0')
# 118 5.0 tensor([[0.9832]], device='cuda:0')
# 119 5.0 tensor([[0.9832]], device='cuda:0')
# 120 5.0 tensor([[0.9828]], device='cuda:0')
# 121 5.0 tensor([[0.9831]], device='cuda:0')
# 122 5.0 tensor([[0.9829]], device='cuda:0')
# 123 5.0 tensor([[0.9832]], device='cuda:0')
# 124 5.0 tensor([[0.9804]], device='cuda:0')
# 125 4.0 tensor([[0.0178]], device='cuda:0')
# 126 2.0 tensor([[0.0178]], device='cuda:0')
# 127 4.0 tensor([[0.0178]], device='cuda:0')
# 128 5.0 tensor([[0.9830]], device='cuda:0')
# 129 5.0 tensor([[0.7588]], device='cuda:0')
# 130 5.0 tensor([[0.9832]], device='cuda:0')
# 131 1.0 tensor([[0.0179]], device='cuda:0')
# 132 5.0 tensor([[0.9831]], device='cuda:0')
# 133 5.0 tensor([[0.9831]], device='cuda:0')
# 134 5.0 tensor([[0.9832]], device='cuda:0')
# 135 2.0 tensor([[0.0178]], device='cuda:0')
# 136 3.0 tensor([[0.0178]], device='cuda:0')
# 137 5.0 tensor([[0.9831]], device='cuda:0')
# 138 5.0 tensor([[0.9832]], device='cuda:0')
# 139 3.0 tensor([[0.0178]], device='cuda:0')
# 140 5.0 tensor([[0.9831]], device='cuda:0')
# 141 5.0 tensor([[0.9831]], device='cuda:0')
# 142 5.0 tensor([[0.9831]], device='cuda:0')
# 143 4.0 tensor([[0.0179]], device='cuda:0')
# 144 5.0 tensor([[0.9831]], device='cuda:0')
# 145 4.0 tensor([[0.0180]], device='cuda:0')
# 146 4.0 tensor([[0.0180]], device='cuda:0')
# 147 4.0 tensor([[0.0180]], device='cuda:0')
# 148 4.0 tensor([[0.0180]], device='cuda:0')
# 149 4.0 tensor([[0.0181]], device='cuda:0')
# 150 5.0 tensor([[0.9820]], device='cuda:0')
# 151 3.0 tensor([[0.0180]], device='cuda:0')
# 152 1.0 tensor([[0.0179]], device='cuda:0')
# 153 5.0 tensor([[0.9832]], device='cuda:0')
# 154 3.0 tensor([[0.0180]], device='cuda:0')
# 155 5.0 tensor([[0.9831]], device='cuda:0')
# 156 1.0 tensor([[0.0178]], device='cuda:0')
# 157 5.0 tensor([[0.9832]], device='cuda:0')
# 158 1.0 tensor([[0.0178]], device='cuda:0')
# 159 2.0 tensor([[0.0178]], device='cuda:0')
# 160 4.0 tensor([[0.0178]], device='cuda:0')
# 161 5.0 tensor([[0.5059]], device='cuda:0')
# 162 5.0 tensor([[0.9832]], device='cuda:0')
# 163 5.0 tensor([[0.9832]], device='cuda:0')
# 164 4.0 tensor([[0.0180]], device='cuda:0')
# 165 3.0 tensor([[0.0179]], device='cuda:0')
# 166 5.0 tensor([[0.9831]], device='cuda:0')
# 167 4.0 tensor([[0.0179]], device='cuda:0')
# 168 3.0 tensor([[0.0179]], device='cuda:0')
# 169 3.0 tensor([[0.0179]], device='cuda:0')
# 170 2.0 tensor([[0.0178]], device='cuda:0')
# 171 5.0 tensor([[0.9832]], device='cuda:0')
# 172 5.0 tensor([[0.9831]], device='cuda:0')
# 173 5.0 tensor([[0.9832]], device='cuda:0')
# 174 1.0 tensor([[0.0178]], device='cuda:0')
# 175 5.0 tensor([[0.9832]], device='cuda:0')
# 176 2.0 tensor([[0.0178]], device='cuda:0')
# 177 5.0 tensor([[0.9832]], device='cuda:0')
# 178 5.0 tensor([[0.9832]], device='cuda:0')
# 179 2.0 tensor([[0.0178]], device='cuda:0')
# 180 3.0 tensor([[0.0181]], device='cuda:0')
# 181 5.0 tensor([[0.9832]], device='cuda:0')
# 182 4.0 tensor([[0.0180]], device='cuda:0')
# 183 5.0 tensor([[0.9831]], device='cuda:0')
# 184 5.0 tensor([[0.9830]], device='cuda:0')
# 185 5.0 tensor([[0.9832]], device='cuda:0')
# 186 4.0 tensor([[0.0178]], device='cuda:0')
# 187 5.0 tensor([[0.9831]], device='cuda:0')
# 188 5.0 tensor([[0.9832]], device='cuda:0')
# 189 5.0 tensor([[0.0184]], device='cuda:0')
# 190 5.0 tensor([[0.9832]], device='cuda:0')
# 191 5.0 tensor([[0.9831]], device='cuda:0')
# 192 1.0 tensor([[0.0181]], device='cuda:0')
# 193 5.0 tensor([[0.9831]], device='cuda:0')
# 194 4.0 tensor([[0.9832]], device='cuda:0')
# 195 5.0 tensor([[0.9831]], device='cuda:0')
# 196 5.0 tensor([[0.9827]], device='cuda:0')
# 197 5.0 tensor([[0.9825]], device='cuda:0')
# 198 5.0 tensor([[0.9831]], device='cuda:0')
# 199 5.0 tensor([[0.9806]], device='cuda:0')
# 200 5.0 tensor([[0.0179]], device='cuda:0')
# 201 4.0 tensor([[0.0179]], device='cuda:0')
# 202 5.0 tensor([[0.0180]], device='cuda:0')
# 203 5.0 tensor([[0.0183]], device='cuda:0')
# 204 5.0 tensor([[0.0581]], device='cuda:0')
# 205 5.0 tensor([[0.9832]], device='cuda:0')
# 206 1.0 tensor([[0.0179]], device='cuda:0')
# 207 5.0 tensor([[0.9832]], device='cuda:0')
# 208 5.0 tensor([[0.9832]], device='cuda:0')
# 209 5.0 tensor([[0.9832]], device='cuda:0')
# 210 5.0 tensor([[0.9614]], device='cuda:0')
# 211 1.0 tensor([[0.0178]], device='cuda:0')
# 212 5.0 tensor([[0.3146]], device='cuda:0')
# 213 4.0 tensor([[0.0179]], device='cuda:0')
# 214 4.0 tensor([[0.0182]], device='cuda:0')
# 215 5.0 tensor([[0.9832]], device='cuda:0')
# 216 5.0 tensor([[0.9832]], device='cuda:0')
# 217 5.0 tensor([[0.9832]], device='cuda:0')
# 218 5.0 tensor([[0.9832]], device='cuda:0')
# 219 1.0 tensor([[0.0178]], device='cuda:0')
# 220 5.0 tensor([[0.9131]], device='cuda:0')
# 221 4.0 tensor([[0.0184]], device='cuda:0')
# 222 4.0 tensor([[0.3547]], device='cuda:0')
# 223 3.0 tensor([[0.0705]], device='cuda:0')
# 224 3.0 tensor([[0.0267]], device='cuda:0')
# 225 5.0 tensor([[0.9831]], device='cuda:0')
# 226 3.0 tensor([[0.0178]], device='cuda:0')
# 227 5.0 tensor([[0.9831]], device='cuda:0')
# 228 5.0 tensor([[0.9832]], device='cuda:0')
# 229 5.0 tensor([[0.9832]], device='cuda:0')
# 230 5.0 tensor([[0.9829]], device='cuda:0')
# 231 5.0 tensor([[0.9830]], device='cuda:0')
# 232 5.0 tensor([[0.9831]], device='cuda:0')
# 233 5.0 tensor([[0.9831]], device='cuda:0')
# 234 5.0 tensor([[0.9831]], device='cuda:0')
# 235 5.0 tensor([[0.9832]], device='cuda:0')
# 236 5.0 tensor([[0.9832]], device='cuda:0')
# 237 1.0 tensor([[0.0178]], device='cuda:0')
# 238 2.0 tensor([[0.0178]], device='cuda:0')
# 239 5.0 tensor([[0.9832]], device='cuda:0')
# 240 5.0 tensor([[0.9832]], device='cuda:0')
# 241 4.0 tensor([[0.3100]], device='cuda:0')
# 242 5.0 tensor([[0.9832]], device='cuda:0')
# 243 5.0 tensor([[0.9832]], device='cuda:0')
# 244 4.0 tensor([[0.3209]], device='cuda:0')
# 245 5.0 tensor([[0.9831]], device='cuda:0')
# 246 5.0 tensor([[0.9831]], device='cuda:0')
# 247 2.0 tensor([[0.0179]], device='cuda:0')
# 248 5.0 tensor([[0.9831]], device='cuda:0')
# 249 5.0 tensor([[0.9827]], device='cuda:0')
# 250 4.0 tensor([[0.0179]], device='cuda:0')
# 251 4.0 tensor([[0.9831]], device='cuda:0')
# 252 1.0 tensor([[0.0179]], device='cuda:0')
# 253 5.0 tensor([[0.9391]], device='cuda:0')
# 254 4.0 tensor([[0.0211]], device='cuda:0')
# 255 4.0 tensor([[0.0842]], device='cuda:0')
# 256 4.0 tensor([[0.0183]], device='cuda:0')
# 257 4.0 tensor([[0.0183]], device='cuda:0')
# 258 1.0 tensor([[0.0178]], device='cuda:0')
# 259 5.0 tensor([[0.9832]], device='cuda:0')
# 260 5.0 tensor([[0.6238]], device='cuda:0')
# 261 5.0 tensor([[0.4591]], device='cuda:0')
# 262 5.0 tensor([[0.9831]], device='cuda:0')
# 263 5.0 tensor([[0.9830]], device='cuda:0')
# 264 5.0 tensor([[0.3084]], device='cuda:0')
# 265 2.0 tensor([[0.0178]], device='cuda:0')
# 266 5.0 tensor([[0.9832]], device='cuda:0')
# 267 5.0 tensor([[0.9832]], device='cuda:0')
# 268 3.0 tensor([[0.9394]], device='cuda:0')
# 269 5.0 tensor([[0.9832]], device='cuda:0')
# 270 1.0 tensor([[0.0178]], device='cuda:0')
# 271 2.0 tensor([[0.0178]], device='cuda:0')
# 272 4.0 tensor([[0.1980]], device='cuda:0')
# 273 5.0 tensor([[0.9832]], device='cuda:0')
# 274 1.0 tensor([[0.0178]], device='cuda:0')
# 275 1.0 tensor([[0.0178]], device='cuda:0')
# 276 5.0 tensor([[0.9832]], device='cuda:0')
# 277 3.0 tensor([[0.0178]], device='cuda:0')
# 278 2.0 tensor([[0.0178]], device='cuda:0')
# 279 5.0 tensor([[0.9832]], device='cuda:0')
# 280 5.0 tensor([[0.9832]], device='cuda:0')
# 281 5.0 tensor([[0.9830]], device='cuda:0')
# 282 5.0 tensor([[0.9832]], device='cuda:0')
# 283 5.0 tensor([[0.9832]], device='cuda:0')
# 284 5.0 tensor([[0.9831]], device='cuda:0')
# 285 4.0 tensor([[0.0178]], device='cuda:0')
# 286 3.0 tensor([[0.0178]], device='cuda:0')
# 287 4.0 tensor([[0.0178]], device='cuda:0')
# 288 2.0 tensor([[0.0178]], device='cuda:0')
# 289 4.0 tensor([[0.0180]], device='cuda:0')
# 290 5.0 tensor([[0.5134]], device='cuda:0')
# 291 5.0 tensor([[0.9832]], device='cuda:0')
# 292 4.0 tensor([[0.0179]], device='cuda:0')
# 293 4.0 tensor([[0.0179]], device='cuda:0')
# 294 5.0 tensor([[0.9832]], device='cuda:0')
# 295 2.0 tensor([[0.0178]], device='cuda:0')
# 296 2.0 tensor([[0.0178]], device='cuda:0')
# 297 5.0 tensor([[0.9832]], device='cuda:0')
# 298 5.0 tensor([[0.9832]], device='cuda:0')
# 299 5.0 tensor([[0.9832]], device='cuda:0')
# 300 5.0 tensor([[0.9832]], device='cuda:0')
# 301 5.0 tensor([[0.9830]], device='cuda:0')
# 302 5.0 tensor([[0.3276]], device='cuda:0')
# 303 5.0 tensor([[0.9831]], device='cuda:0')
# 304 5.0 tensor([[0.9832]], device='cuda:0')
# 305 1.0 tensor([[0.0179]], device='cuda:0')
# 306 5.0 tensor([[0.9831]], device='cuda:0')
# 307 5.0 tensor([[0.9831]], device='cuda:0')
# 308 5.0 tensor([[0.0183]], device='cuda:0')
# 309 4.0 tensor([[0.0180]], device='cuda:0')
# 310 5.0 tensor([[0.9832]], device='cuda:0')
# 311 5.0 tensor([[0.9832]], device='cuda:0')
# 312 5.0 tensor([[0.9832]], device='cuda:0')
# 313 4.0 tensor([[0.0179]], device='cuda:0')
# 314 5.0 tensor([[0.9831]], device='cuda:0')
# 315 5.0 tensor([[0.9831]], device='cuda:0')
# 316 5.0 tensor([[0.9832]], device='cuda:0')
# 317 2.0 tensor([[0.0179]], device='cuda:0')
# 318 5.0 tensor([[0.9831]], device='cuda:0')
# 319 5.0 tensor([[0.9822]], device='cuda:0')
# 320 5.0 tensor([[0.9832]], device='cuda:0')
# 321 4.0 tensor([[0.9832]], device='cuda:0')
# 322 1.0 tensor([[0.0178]], device='cuda:0')
# 323 5.0 tensor([[0.9832]], device='cuda:0')
# 324 1.0 tensor([[0.0178]], device='cuda:0')
# 325 3.0 tensor([[0.0178]], device='cuda:0')
# 326 5.0 tensor([[0.9832]], device='cuda:0')
# 327 3.0 tensor([[0.0179]], device='cuda:0')
# 328 3.0 tensor([[0.0178]], device='cuda:0')
# 329 4.0 tensor([[0.1397]], device='cuda:0')
# 330 1.0 tensor([[0.0179]], device='cuda:0')
# 331 5.0 tensor([[0.9832]], device='cuda:0')
# 332 5.0 tensor([[0.9832]], device='cuda:0')
# 333 5.0 tensor([[0.9832]], device='cuda:0')
# 334 5.0 tensor([[0.9832]], device='cuda:0')
# 335 4.0 tensor([[0.1985]], device='cuda:0')
# 336 5.0 tensor([[0.9831]], device='cuda:0')
# 337 5.0 tensor([[0.9831]], device='cuda:0')
# 338 4.0 tensor([[0.0179]], device='cuda:0')
# 339 3.0 tensor([[0.0179]], device='cuda:0')
# 340 5.0 tensor([[0.9832]], device='cuda:0')
# 341 5.0 tensor([[0.9832]], device='cuda:0')
# 342 5.0 tensor([[0.9832]], device='cuda:0')
# 343 1.0 tensor([[0.0178]], device='cuda:0')
# 344 2.0 tensor([[0.0178]], device='cuda:0')
# 345 4.0 tensor([[0.0178]], device='cuda:0')
# 346 5.0 tensor([[0.9832]], device='cuda:0')
# 347 3.0 tensor([[0.0178]], device='cuda:0')
# 348 4.0 tensor([[0.0179]], device='cuda:0')
# 349 5.0 tensor([[0.9832]], device='cuda:0')
# 350 5.0 tensor([[0.9831]], device='cuda:0')
# 351 5.0 tensor([[0.9831]], device='cuda:0')
# 352 4.0 tensor([[0.0179]], device='cuda:0')
# 353 5.0 tensor([[0.9831]], device='cuda:0')
# 354 5.0 tensor([[0.9831]], device='cuda:0')
# 355 5.0 tensor([[0.9831]], device='cuda:0')
# 356 4.0 tensor([[0.2190]], device='cuda:0')
# 357 5.0 tensor([[0.9832]], device='cuda:0')
# 358 5.0 tensor([[0.9831]], device='cuda:0')
# 359 3.0 tensor([[0.0179]], device='cuda:0')
# 360 3.0 tensor([[0.0183]], device='cuda:0')
# 361 1.0 tensor([[0.0179]], device='cuda:0')
# 362 3.0 tensor([[0.0179]], device='cuda:0')
# 363 5.0 tensor([[0.9832]], device='cuda:0')
# 364 5.0 tensor([[0.9832]], device='cuda:0')
# 365 5.0 tensor([[0.9790]], device='cuda:0')
# 366 5.0 tensor([[0.2009]], device='cuda:0')
# 367 2.0 tensor([[0.0178]], device='cuda:0')
# 368 5.0 tensor([[0.8219]], device='cuda:0')
# 369 2.0 tensor([[0.0178]], device='cuda:0')
# 370 5.0 tensor([[0.9832]], device='cuda:0')
# 371 5.0 tensor([[0.9832]], device='cuda:0')
# 372 2.0 tensor([[0.0179]], device='cuda:0')
# 373 5.0 tensor([[0.9831]], device='cuda:0')
# 374 5.0 tensor([[0.9832]], device='cuda:0')
# 375 5.0 tensor([[0.9832]], device='cuda:0')
# 376 4.0 tensor([[0.0180]], device='cuda:0')
# 377 5.0 tensor([[0.9832]], device='cuda:0')
# 378 5.0 tensor([[0.9832]], device='cuda:0')
# 379 5.0 tensor([[0.9832]], device='cuda:0')
# 380 5.0 tensor([[0.9568]], device='cuda:0')
# 381 4.0 tensor([[0.0179]], device='cuda:0')
# 382 5.0 tensor([[0.9828]], device='cuda:0')
# 383 1.0 tensor([[0.0180]], device='cuda:0')
# 384 5.0 tensor([[0.9810]], device='cuda:0')
# 385 5.0 tensor([[0.9831]], device='cuda:0')
# 386 1.0 tensor([[0.0179]], device='cuda:0')
# 387 4.0 tensor([[0.0179]], device='cuda:0')
# 388 5.0 tensor([[0.9814]], device='cuda:0')
# 389 4.0 tensor([[0.0179]], device='cuda:0')
# 390 5.0 tensor([[0.4862]], device='cuda:0')
# 391 5.0 tensor([[0.0343]], device='cuda:0')
# 392 5.0 tensor([[0.9558]], device='cuda:0')
# 393 3.0 tensor([[0.0179]], device='cuda:0')
# 394 5.0 tensor([[0.9531]], device='cuda:0')
# 395 3.0 tensor([[0.0178]], device='cuda:0')
# 396 4.0 tensor([[0.0179]], device='cuda:0')
# 397 1.0 tensor([[0.0178]], device='cuda:0')
# 398 4.0 tensor([[0.0179]], device='cuda:0')
# 399 4.0 tensor([[0.0179]], device='cuda:0')
# 400 4.0 tensor([[0.0178]], device='cuda:0')
# 401 4.0 tensor([[0.0179]], device='cuda:0')
# 402 4.0 tensor([[0.0179]], device='cuda:0')
# 403 4.0 tensor([[0.0178]], device='cuda:0')
# 404 4.0 tensor([[0.0179]], device='cuda:0')
# 405 4.0 tensor([[0.0178]], device='cuda:0')
# 406 1.0 tensor([[0.0178]], device='cuda:0')
# 407 4.0 tensor([[0.0178]], device='cuda:0')
# 408 5.0 tensor([[0.9832]], device='cuda:0')
# 409 5.0 tensor([[0.9832]], device='cuda:0')
# 410 5.0 tensor([[0.9832]], device='cuda:0')
# 411 5.0 tensor([[0.9832]], device='cuda:0')
# 412 1.0 tensor([[0.0952]], device='cuda:0')
# 413 5.0 tensor([[0.9828]], device='cuda:0')
# 414 4.0 tensor([[0.0179]], device='cuda:0')
# 415 5.0 tensor([[0.9832]], device='cuda:0')
# 416 2.0 tensor([[0.0178]], device='cuda:0')
# 417 5.0 tensor([[0.9832]], device='cuda:0')
# 418 5.0 tensor([[0.9831]], device='cuda:0')
# 419 4.0 tensor([[0.0179]], device='cuda:0')
# 420 5.0 tensor([[0.9831]], device='cuda:0')
# 421 2.0 tensor([[0.0178]], device='cuda:0')
# 422 2.0 tensor([[0.0178]], device='cuda:0')
# 423 5.0 tensor([[0.9832]], device='cuda:0')
# 424 5.0 tensor([[0.9832]], device='cuda:0')
# 425 1.0 tensor([[0.0178]], device='cuda:0')
# 426 5.0 tensor([[0.9832]], device='cuda:0')
# 427 5.0 tensor([[0.9831]], device='cuda:0')
# 428 1.0 tensor([[0.0178]], device='cuda:0')
# 429 3.0 tensor([[0.0181]], device='cuda:0')
# 430 5.0 tensor([[0.9831]], device='cuda:0')
# 431 5.0 tensor([[0.9831]], device='cuda:0')
# 432 5.0 tensor([[0.9831]], device='cuda:0')
# 433 5.0 tensor([[0.9831]], device='cuda:0')
# 434 5.0 tensor([[0.9831]], device='cuda:0')
# 435 5.0 tensor([[0.9832]], device='cuda:0')
# 436 5.0 tensor([[0.9832]], device='cuda:0')
# 437 1.0 tensor([[0.0178]], device='cuda:0')
# 438 5.0 tensor([[0.9232]], device='cuda:0')
# 439 5.0 tensor([[0.0178]], device='cuda:0')
# 440 5.0 tensor([[0.0182]], device='cuda:0')
# 441 5.0 tensor([[0.9832]], device='cuda:0')
# 442 5.0 tensor([[0.9832]], device='cuda:0')
# 443 1.0 tensor([[0.0178]], device='cuda:0')
# 444 5.0 tensor([[0.9831]], device='cuda:0')
# 445 5.0 tensor([[0.9831]], device='cuda:0')
# 446 4.0 tensor([[0.0181]], device='cuda:0')
# 447 4.0 tensor([[0.0181]], device='cuda:0')
# 448 5.0 tensor([[0.9832]], device='cuda:0')
# 449 5.0 tensor([[0.9805]], device='cuda:0')
# 450 5.0 tensor([[0.0186]], device='cuda:0')
# 451 5.0 tensor([[0.0882]], device='cuda:0')
# 452 5.0 tensor([[0.0186]], device='cuda:0')
# 453 5.0 tensor([[0.9297]], device='cuda:0')
# 454 5.0 tensor([[0.0198]], device='cuda:0')
# 455 5.0 tensor([[0.9832]], device='cuda:0')
# 456 5.0 tensor([[0.9832]], device='cuda:0')
# 457 4.0 tensor([[0.0186]], device='cuda:0')
# 458 5.0 tensor([[0.9831]], device='cuda:0')
# 459 5.0 tensor([[0.9832]], device='cuda:0')
# 460 1.0 tensor([[0.0179]], device='cuda:0')
# 461 5.0 tensor([[0.9831]], device='cuda:0')
# 462 5.0 tensor([[0.9831]], device='cuda:0')
# 463 1.0 tensor([[0.0179]], device='cuda:0')
# 464 5.0 tensor([[0.9831]], device='cuda:0')
# 465 3.0 tensor([[0.0184]], device='cuda:0')
# 466 5.0 tensor([[0.9831]], device='cuda:0')
# 467 2.0 tensor([[0.0179]], device='cuda:0')
# 468 2.0 tensor([[0.0179]], device='cuda:0')
# 469 2.0 tensor([[0.0179]], device='cuda:0')
# 470 5.0 tensor([[0.9832]], device='cuda:0')
# 471 5.0 tensor([[0.9832]], device='cuda:0')
# 472 2.0 tensor([[0.0178]], device='cuda:0')
# 473 5.0 tensor([[0.9832]], device='cuda:0')
# 474 5.0 tensor([[0.9832]], device='cuda:0')
# 475 5.0 tensor([[0.9832]], device='cuda:0')
# 476 5.0 tensor([[0.9832]], device='cuda:0')
# 477 3.0 tensor([[0.0193]], device='cuda:0')
# 478 3.0 tensor([[0.0179]], device='cuda:0')
# 479 4.0 tensor([[0.0179]], device='cuda:0')
# 480 5.0 tensor([[0.9832]], device='cuda:0')
# 481 5.0 tensor([[0.9832]], device='cuda:0')
# 482 1.0 tensor([[0.0178]], device='cuda:0')
# 483 5.0 tensor([[0.9832]], device='cuda:0')
# 484 4.0 tensor([[0.0178]], device='cuda:0')
# 485 5.0 tensor([[0.9771]], device='cuda:0')
# 486 5.0 tensor([[0.2540]], device='cuda:0')
# 487 4.0 tensor([[0.0179]], device='cuda:0')
# 488 5.0 tensor([[0.9796]], device='cuda:0')
# 489 5.0 tensor([[0.2387]], device='cuda:0')
# 490 5.0 tensor([[0.6923]], device='cuda:0')
# 491 5.0 tensor([[0.9831]], device='cuda:0')
# 492 1.0 tensor([[0.0178]], device='cuda:0')
# 493 4.0 tensor([[0.4900]], device='cuda:0')
# 494 4.0 tensor([[0.0282]], device='cuda:0')
# 495 5.0 tensor([[0.9832]], device='cuda:0')
# 496 5.0 tensor([[0.0183]], device='cuda:0')
# 497 5.0 tensor([[0.9832]], device='cuda:0')
# 498 1.0 tensor([[0.0178]], device='cuda:0')
# 499 2.0 tensor([[0.0178]], device='cuda:0')
# 500 1.0 tensor([[0.0178]], device='cuda:0')
# 501 5.0 tensor([[0.9827]], device='cuda:0')
# 502 5.0 tensor([[0.9831]], device='cuda:0')
# 503 5.0 tensor([[0.0178]], device='cuda:0')
# 504 4.0 tensor([[0.9832]], device='cuda:0')
# 505 5.0 tensor([[0.9829]], device='cuda:0')
# 506 2.0 tensor([[0.0179]], device='cuda:0')
# 507 5.0 tensor([[0.9826]], device='cuda:0')
# 508 4.0 tensor([[0.0180]], device='cuda:0')
# 509 1.0 tensor([[0.0179]], device='cuda:0')
# 510 1.0 tensor([[0.0720]], device='cuda:0')
# 511 5.0 tensor([[0.0180]], device='cuda:0')
# 512 5.0 tensor([[0.8500]], device='cuda:0')
# 513 1.0 tensor([[0.0517]], device='cuda:0')
# 514 3.0 tensor([[0.0180]], device='cuda:0')
# 515 4.0 tensor([[0.9831]], device='cuda:0')
# 516 5.0 tensor([[0.9832]], device='cuda:0')
# 517 1.0 tensor([[0.9831]], device='cuda:0')
# 518 4.0 tensor([[0.9829]], device='cuda:0')
# 519 4.0 tensor([[0.0179]], device='cuda:0')
# 520 1.0 tensor([[0.0179]], device='cuda:0')
# 521 4.0 tensor([[0.9831]], device='cuda:0')
# 522 5.0 tensor([[0.0181]], device='cuda:0')
# 523 1.0 tensor([[0.0179]], device='cuda:0')
# 524 3.0 tensor([[0.0179]], device='cuda:0')
# 525 1.0 tensor([[0.9831]], device='cuda:0')
# 526 4.0 tensor([[0.9832]], device='cuda:0')
# 527 5.0 tensor([[0.9800]], device='cuda:0')
# 528 1.0 tensor([[0.9819]], device='cuda:0')
# 529 2.0 tensor([[0.9831]], device='cuda:0')
# 530 4.0 tensor([[0.9831]], device='cuda:0')
# 531 1.0 tensor([[0.9832]], device='cuda:0')
# 532 5.0 tensor([[0.9832]], device='cuda:0')
# 533 5.0 tensor([[0.9828]], device='cuda:0')
# 534 4.0 tensor([[0.9679]], device='cuda:0')
# 535 5.0 tensor([[0.0178]], device='cuda:0')
# 536 1.0 tensor([[0.0178]], device='cuda:0')
# 537 5.0 tensor([[0.2626]], device='cuda:0')
# 538 5.0 tensor([[0.0228]], device='cuda:0')
# 539 5.0 tensor([[0.0228]], device='cuda:0')
# 540 1.0 tensor([[0.0646]], device='cuda:0')
# 541 4.0 tensor([[0.0219]], device='cuda:0')
# 542 4.0 tensor([[0.9831]], device='cuda:0')
# 543 4.0 tensor([[0.0219]], device='cuda:0')
# 544 4.0 tensor([[0.9722]], device='cuda:0')
# 545 5.0 tensor([[0.0181]], device='cuda:0')
# 546 4.0 tensor([[0.0222]], device='cuda:0')
# 547 1.0 tensor([[0.2183]], device='cuda:0')
# 548 5.0 tensor([[0.0182]], device='cuda:0')
# 549 5.0 tensor([[0.0181]], device='cuda:0')
# 550 5.0 tensor([[0.0428]], device='cuda:0')
# 551 5.0 tensor([[0.0178]], device='cuda:0')
# 552 5.0 tensor([[0.0178]], device='cuda:0')
# 553 5.0 tensor([[0.9832]], device='cuda:0')
# 554 5.0 tensor([[0.0178]], device='cuda:0')
# 555 5.0 tensor([[0.0178]], device='cuda:0')
# 556 5.0 tensor([[0.9832]], device='cuda:0')
# 557 1.0 tensor([[0.9832]], device='cuda:0')
# 558 1.0 tensor([[0.9832]], device='cuda:0')
# 559 5.0 tensor([[0.9832]], device='cuda:0')
# 560 5.0 tensor([[0.4973]], device='cuda:0')
# 561 5.0 tensor([[0.6276]], device='cuda:0')
# 562 5.0 tensor([[0.9832]], device='cuda:0')
# 563 5.0 tensor([[0.9832]], device='cuda:0')
# 564 5.0 tensor([[0.9832]], device='cuda:0')
# 565 1.0 tensor([[0.5761]], device='cuda:0')
# 566 1.0 tensor([[0.3752]], device='cuda:0')
# 567 5.0 tensor([[0.0179]], device='cuda:0')
# 568 5.0 tensor([[0.9823]], device='cuda:0')
# 569 1.0 tensor([[0.3815]], device='cuda:0')
# 570 3.0 tensor([[0.0183]], device='cuda:0')
# 571 5.0 tensor([[0.9832]], device='cuda:0')
# 572 5.0 tensor([[0.0179]], device='cuda:0')
# 573 5.0 tensor([[0.0196]], device='cuda:0')
# 574 2.0 tensor([[0.9832]], device='cuda:0')
# 575 5.0 tensor([[0.9832]], device='cuda:0')
# 576 5.0 tensor([[0.0257]], device='cuda:0')
# 577 5.0 tensor([[0.9832]], device='cuda:0')
# 578 4.0 tensor([[0.9832]], device='cuda:0')
# 579 5.0 tensor([[0.0181]], device='cuda:0')
# 580 5.0 tensor([[0.0178]], device='cuda:0')
# 581 5.0 tensor([[0.9832]], device='cuda:0')
# 582 2.0 tensor([[0.0179]], device='cuda:0')
# 583 5.0 tensor([[0.9830]], device='cuda:0')
# 584 2.0 tensor([[0.0180]], device='cuda:0')
# 585 4.0 tensor([[0.9719]], device='cuda:0')
# 586 5.0 tensor([[0.9831]], device='cuda:0')
# 587 4.0 tensor([[0.9823]], device='cuda:0')
# 588 4.0 tensor([[0.0183]], device='cuda:0')
# 589 5.0 tensor([[0.9831]], device='cuda:0')
# 590 5.0 tensor([[0.0336]], device='cuda:0')
# 591 1.0 tensor([[0.1772]], device='cuda:0')
# 592 5.0 tensor([[0.2960]], device='cuda:0')
# 593 1.0 tensor([[0.9642]], device='cuda:0')
# 594 5.0 tensor([[0.0179]], device='cuda:0')
# 595 5.0 tensor([[0.9832]], device='cuda:0')
# 596 5.0 tensor([[0.0182]], device='cuda:0')
# 597 5.0 tensor([[0.9832]], device='cuda:0')
# 598 1.0 tensor([[0.9832]], device='cuda:0')
# 599 1.0 tensor([[0.0178]], device='cuda:0')
# 600 1.0 tensor([[0.0178]], device='cuda:0')
# 601 5.0 tensor([[0.9827]], device='cuda:0')
# 602 5.0 tensor([[0.9831]], device='cuda:0')
# 603 3.0 tensor([[0.0178]], device='cuda:0')
# 604 5.0 tensor([[0.9832]], device='cuda:0')
# 605 5.0 tensor([[0.9829]], device='cuda:0')
# 606 2.0 tensor([[0.0179]], device='cuda:0')
# 607 4.0 tensor([[0.9826]], device='cuda:0')
# 608 5.0 tensor([[0.0180]], device='cuda:0')
# 609 5.0 tensor([[0.0179]], device='cuda:0')
# 610 5.0 tensor([[0.0720]], device='cuda:0')
# 611 2.0 tensor([[0.0180]], device='cuda:0')
# 612 5.0 tensor([[0.8500]], device='cuda:0')
# 613 4.0 tensor([[0.0517]], device='cuda:0')
# 614 2.0 tensor([[0.0180]], device='cuda:0')
# 615 4.0 tensor([[0.9831]], device='cuda:0')
# 616 5.0 tensor([[0.9832]], device='cuda:0')
# 617 5.0 tensor([[0.9831]], device='cuda:0')
# 618 5.0 tensor([[0.9829]], device='cuda:0')
# 619 5.0 tensor([[0.0179]], device='cuda:0')
# 620 4.0 tensor([[0.0179]], device='cuda:0')
# 621 5.0 tensor([[0.9831]], device='cuda:0')
# 622 3.0 tensor([[0.0181]], device='cuda:0')
# 623 4.0 tensor([[0.0179]], device='cuda:0')
# 624 4.0 tensor([[0.0179]], device='cuda:0')
# 625 5.0 tensor([[0.9831]], device='cuda:0')
# 626 5.0 tensor([[0.9832]], device='cuda:0')
# 627 5.0 tensor([[0.9800]], device='cuda:0')
# 628 5.0 tensor([[0.9819]], device='cuda:0')
# 629 5.0 tensor([[0.9831]], device='cuda:0')
# 630 5.0 tensor([[0.9831]], device='cuda:0')
# 631 5.0 tensor([[0.9832]], device='cuda:0')
# 632 5.0 tensor([[0.9832]], device='cuda:0')
# 633 5.0 tensor([[0.9828]], device='cuda:0')
# 634 5.0 tensor([[0.9679]], device='cuda:0')
# 635 4.0 tensor([[0.0178]], device='cuda:0')
# 636 4.0 tensor([[0.0178]], device='cuda:0')
# 637 5.0 tensor([[0.2626]], device='cuda:0')
# 638 5.0 tensor([[0.0228]], device='cuda:0')
# 639 5.0 tensor([[0.0228]], device='cuda:0')
# 640 4.0 tensor([[0.0646]], device='cuda:0')
# 641 5.0 tensor([[0.0219]], device='cuda:0')
# 642 4.0 tensor([[0.9831]], device='cuda:0')
# 643 5.0 tensor([[0.0219]], device='cuda:0')
# 644 4.0 tensor([[0.9722]], device='cuda:0')
# 645 4.0 tensor([[0.0181]], device='cuda:0')
# 646 1.0 tensor([[0.0222]], device='cuda:0')
# 647 1.0 tensor([[0.2183]], device='cuda:0')
# 648 4.0 tensor([[0.0182]], device='cuda:0')
# 649 4.0 tensor([[0.0181]], device='cuda:0')
# 650 5.0 tensor([[0.0428]], device='cuda:0')
# 651 4.0 tensor([[0.0178]], device='cuda:0')
# 652 1.0 tensor([[0.0178]], device='cuda:0')
# 653 5.0 tensor([[0.9832]], device='cuda:0')
# 654 4.0 tensor([[0.0178]], device='cuda:0')
# 655 1.0 tensor([[0.0178]], device='cuda:0')
# 656 5.0 tensor([[0.9832]], device='cuda:0')
# 657 5.0 tensor([[0.9832]], device='cuda:0')
# 658 5.0 tensor([[0.9832]], device='cuda:0')
# 659 5.0 tensor([[0.9832]], device='cuda:0')
# 660 5.0 tensor([[0.4973]], device='cuda:0')
# 661 5.0 tensor([[0.6276]], device='cuda:0')
# 662 5.0 tensor([[0.9832]], device='cuda:0')
# 663 5.0 tensor([[0.9832]], device='cuda:0')
# 664 5.0 tensor([[0.9832]], device='cuda:0')
# 665 4.0 tensor([[0.5761]], device='cuda:0')
# 666 5.0 tensor([[0.3752]], device='cuda:0')
# 667 3.0 tensor([[0.0179]], device='cuda:0')
# 668 4.0 tensor([[0.9823]], device='cuda:0')
# 669 3.0 tensor([[0.3815]], device='cuda:0')
# 670 5.0 tensor([[0.0183]], device='cuda:0')
# 671 5.0 tensor([[0.9832]], device='cuda:0')
# 672 5.0 tensor([[0.0179]], device='cuda:0')
# 673 5.0 tensor([[0.0196]], device='cuda:0')
# 674 5.0 tensor([[0.9832]], device='cuda:0')
# 675 5.0 tensor([[0.9832]], device='cuda:0')
# 676 1.0 tensor([[0.0257]], device='cuda:0')
# 677 5.0 tensor([[0.9832]], device='cuda:0')
# 678 5.0 tensor([[0.9832]], device='cuda:0')
# 679 2.0 tensor([[0.0181]], device='cuda:0')
# 680 3.0 tensor([[0.0178]], device='cuda:0')
# 681 5.0 tensor([[0.9832]], device='cuda:0')
# 682 5.0 tensor([[0.0179]], device='cuda:0')
# 683 2.0 tensor([[0.9830]], device='cuda:0')
# 684 5.0 tensor([[0.0180]], device='cuda:0')
# 685 5.0 tensor([[0.9719]], device='cuda:0')
# 686 5.0 tensor([[0.9831]], device='cuda:0')
# 687 5.0 tensor([[0.9823]], device='cuda:0')
# 688 2.0 tensor([[0.0183]], device='cuda:0')
# 689 5.0 tensor([[0.9831]], device='cuda:0')
# 690 3.0 tensor([[0.0336]], device='cuda:0')
# 691 4.0 tensor([[0.1772]], device='cuda:0')
# 692 2.0 tensor([[0.2960]], device='cuda:0')
# 693 5.0 tensor([[0.9642]], device='cuda:0')
# 694 2.0 tensor([[0.0179]], device='cuda:0')
# 695 5.0 tensor([[0.9832]], device='cuda:0')
# 696 5.0 tensor([[0.0182]], device='cuda:0')
# 697 5.0 tensor([[0.9832]], device='cuda:0')
# 698 5.0 tensor([[0.9832]], device='cuda:0')
# 699 5.0 tensor([[0.0178]], device='cuda:0')
